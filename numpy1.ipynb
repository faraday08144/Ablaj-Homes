# %% [markdown]
# <a href="https://colab.research.google.com/github/faraday08144/Ablaj-Homes/blob/main/numpy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from numpy import random
x = random.randint(100)
print(x)
# Out:
# 14

# %%
x1 =random.randint(100, size=(3,3,3))
print(x1)
# Out:
# [[[50 46 24]
#   [43 27 70]
#   [13 47 35]]
#
#  [[36 37  6]
#   [33 96 13]
#   [17 23 70]]
#
#  [[41 56 22]
#   [ 0 20 85]
#   [43 32 88]]]

# %%
x2 = random.choice([3,5,7,9], p = [0.1,0.3,0.5,0.1], size=(100))
print(x2)
# Out:
# [9 7 7 7 7 5 7 7 3 5 7 7 7 5 7 5 7 9 7 9 7 3 7 5 5 7 7 9 5 5 3 3 5 7 7 7 5
#  3 7 7 7 7 7 7 7 7 7 7 7 7 7 7 5 7 5 5 9 7 5 5 7 5 7 5 9 7 7 7 3 3 9 7 7 7
#  7 7 7 5 5 5 7 7 5 7 5 7 5 7 7 3 9 9 7 5 5 7 7 7 7 5]

# %%
x3 = random.randint(20, size=(2,3,2))
 #print(x3)
print(random.permutation(x3))
# Out:
# [[[ 4 13]
#   [19  9]
#   [ 3  8]]
#
#  [[ 7 18]
#   [ 8 18]
#   [ 3 15]]]
